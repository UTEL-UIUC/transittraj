# %%
from google.cloud import storage
import pandas as pd

# %%
df = pd.read_parquet(path = "lacmta_tides_rail_05-27-26.parquet",
                     engine = "pyarrow")

# %%
df.size
# Out:
# 1245888

# %%
df.to_csv("lacmta_tides_rail_05-27-26.csv")
